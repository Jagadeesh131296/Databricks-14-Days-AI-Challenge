# %%
# %sql
CREATE CATALOG ecommercetest;
USE CATALOG ecommercetest;
CREATE SCHEMA bronze;
CREATE SCHEMA silver;
CREATE SCHEMA gold;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %%
display(spark.sql('DESCRIBE DETAIL delta.`/Volumes/workspace/ecommerce/ecommerce_data/bronze/events`'))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
# %sql
CREATE TABLE ecommercetest.bronze.events
USING DELTA
select * from delta.`/Volumes/workspace/ecommerce/ecommerce_data/bronze/events`;

# %%
# %sql
CREATE TABLE ecommercetest.silver.silverevents
USING DELTA
select * from delta.`/Volumes/workspace/ecommerce/ecommerce_data/silver/events`;

# %%
# %sql
CREATE TABLE ecommercetest.gold.products
USING DELTA
select * from delta.`/Volumes/workspace/ecommerce/ecommerce_data/gold/products`;

# %%
# %sql
-- Permissions
GRANT SELECT ON TABLE gold.products TO `js.jagan1996@gmail.com`;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %%
spark.sql('GRANT ALL PRIVILEGES ON SCHEMA silver TO `js.jagan1996@gmail.com`;')
# Out:
# DataFrame[]

# %%
# %sql
-- Controlled view
CREATE VIEW gold.top_products AS
SELECT brand, revenue, conversion_rate
FROM gold.products
WHERE purchases > 10
ORDER BY revenue DESC LIMIT 100;
