# %%
# Create simple DataFrame
data = [("iPhone", 999), ("Samsung", 799), ("MacBook", 1299)]
df_test = spark.createDataFrame(data, ["product", "price"])
df_test.show()

df_test.filter(df_test.price > 1000).show()
# Out:
# +-------+-----+
# |product|price|
# +-------+-----+
# | iPhone|  999|
# |Samsung|  799|
# |MacBook| 1299|
# +-------+-----+
#
# +-------+-----+
# |product|price|
# +-------+-----+
# |MacBook| 1299|
# +-------+-----+

# %%
# Filter expensive products
# Out:
# +-------+-----+
# |product|price|
# +-------+-----+
# |MacBook| 1299|
# +-------+-----+
